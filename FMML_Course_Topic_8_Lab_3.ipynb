# %% [markdown]
# <a href="https://colab.research.google.com/github/mahankali777/FMML-PROJECTS-AND-LABS-2024/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 15:53:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  54.9MB/s    in 1.3s
#
# 2024-03-30 15:53:10 (54.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36630   1112.0791v1  We introduce the framework of qualitative opti...    cs
# 6935   1707.07785v1  Relational probabilistic models have the chall...  stat
# 22069   1409.7193v2  Significant attention has been given to minimi...  stat
# 22673  1704.01430v1  We study a model where one target variable Y i...  stat
# 24607   1409.3913v1  In object tracking, outlier is one of primary ...    cs
# ...             ...                                                ...   ...
# 27218  1702.08272v2  We present a new public dataset with a focus o...    cs
# 25828  1511.08446v1  Learning the distribution of images in order t...    cs
# 23285   1012.2491v1  We revisit the problem of model-based object r...    cs
# 17147  1708.09496v1  To understand narrative, humans draw inference...    cs
# 29242  1708.08325v1  DeepPrior is a simple approach based on Deep L...    cs
#
#                                                    title  year  \
# 36630  Strong Equivalence of Qualitative Optimization...  2011
# 6935   Comparing Aggregators for Relational Probabili...  2017
# 22069    MIST: L0 Sparse Linear Regression with Momentum  2014
# 22673  Detecting confounding in multivariate linear m...  2017
# 24607        Concurrent Tracking of Inliers and Outliers  2014
# ...                                                  ...   ...
# 27218  A Dataset for Developing and Benchmarking Acti...  2017
# 25828  Towards Automatic Image Editing: Learning to S...  2015
# 23285  Affine Invariant, Model-Based Object Recogniti...  2010
# 17147  Inferring Narrative Causality between Event Pa...  2017
# 29242  DeepPrior++: Improving Fast and Accurate 3D Ha...  2017
#
#                                                 keywords
# 36630  [introduce, framework, qualitative, optimizati...
# 6935   [relational, probabilistic, challenge, aggrega...
# 22069  [significant, attention, minimizing, penalized...
# 22673  [correlated, predictor, variables, potential, ...
# 24607  [performance, algorithms, therefore, attention...
# ...                                                  ...
# 27218  [simulating, environments, instances, detectio...
# 25828  [distribution, challenging, dimensionality, re...
# 23285  [recognition, intensity, shortcomings, unsuita...
# 17147  [understand, narrative, inferences, underlying...
# 29242  [deepprior, locations, publication, outperform...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36630    [introduce, framework, qualitative, optimizati...
# 6935     [relational, probabilistic, challenge, aggrega...
# 22069    [significant, attention, minimizing, penalized...
# 22673    [correlated, predictor, variables, potential, ...
# 24607    [performance, algorithms, therefore, attention...
#                                ...
# 30183    [comparison, simulated, automobile, trajectori...
# 1190     [convolutional, performance, classification, d...
# 670      [informatics, application, processing, assista...
# 15279    [researchers, entailment, inferences, involvin...
# 35683    [environments, individual, monitoring, effecti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8818 words.
# Out of those 4576 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9de5b8e6-0e9e-4b65-a1c7-7d3989336b44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9de5b8e6-0e9e-4b65-a1c7-7d3989336b44")) {                    Plotly.newPlot(                        "9de5b8e6-0e9e-4b65-a1c7-7d3989336b44",                        [{"x":["semantics","extensions","optimization","equilibrium","rewriting","represent","characterize","reasoning","establish","understanding","properties","generalize","propositional","preference","interpreted","interpretation","framework","associated","equivalence","essential","formalism","complexity","introduce","interchangeability","representation","restricting","generators","preferences","guarantees","previously","techniques","generator","qualitative","variables","probabilistic","empirical","different","numerical","shortcomings","overconfidence","foundation","surprisingly","regression","population","intuition","representations","challenge","outperform","aggregation","information","modifications","understood","relational","correspond","empirically","predicting","comparing","challenging","performance","minimizer","equations","simulations","shrinkage","criterion","solutions","thresholding","resulting","responsible","iterative","minimizing","convergence","attention","estimating","significant","algorithm","penalized","confounder","confounding","typically","multivariate","dimensions","detecting","influence","characteristic","concentration","eigenspaces","dependences","predictor","coefficients","quantitatively","covariance","potential","correlated","assumption","describing","independence","statistical","orientation","practical","algorithms","accelerator","sequences","therefore","occlusion","estimated","implementation","important","concurrent","estimation","employing","experimental","pyramidal","benchmark","correlates","parameter","stochastic","parameters","blackwellized","variational","similarities","gradients","efficiently","parallelized","inference","interesting","distribution","expectation","continuous","performing","intelligently","constructing","furthermore","trivially","illustrated","universal","percentage","weighting","consequences","consistency","simulated","existence","minimization","equivalent","benchmarks","substantially","conditions","theoretical","contributions","reinterpret","achieving","linearity","workhorse","impressive","following","demonstrate","substantial","knowledge","incorporates","significance","perceptual","structure","isolation","interests","efficient","principled","heuristic","scenarios","iteration","increasingly","especially","catastrophic","including","theoretically","assumptions","reachable","relationships","unavoidable","restrictive","preliminary","optimally","generally","investigated","experiences","introduces","experiments","confidence","subspaces","experience","calculates","increasing","exploiting","suggested","detriment","nevertheless","reinforcement","computational","generalization","additionally","intervals","designing"],"y":[89,41,283,23,3,115,50,129,50,166,223,51,25,19,25,43,570,107,20,69,15,216,324,2,346,12,14,28,68,103,370,23,53,121,137,154,740,73,15,1,12,30,129,44,19,247,135,86,26,695,15,26,38,23,74,91,70,260,909,3,23,47,3,51,139,21,146,12,78,43,118,181,63,234,790,4,0,2,105,22,43,60,64,25,14,1,0,14,38,27,14,143,28,63,24,25,138,31,143,593,5,104,145,28,53,150,392,5,189,35,365,5,224,2,109,116,245,0,62,44,29,138,7,218,77,231,28,95,88,4,43,168,1,16,40,15,15,10,63,71,29,56,44,88,37,146,155,50,2,60,9,1,27,74,570,37,325,37,15,16,344,13,16,429,31,66,79,51,54,122,3,252,50,77,7,69,7,13,49,17,70,50,14,60,587,43,21,37,1,123,71,32,1,27,108,282,110,58,10,39],"type":"bar"},{"x":["semantics","extensions","optimization","equilibrium","rewriting","represent" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4576,), (4576, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>GRASS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Recursive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Autoencoders</span> <span style=''>for</span> <span style=''>Shape</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structures</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.5533333333333332);'>architecture</span> <span style=''>for</span> <span style=''>encoding</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.702127659574468);'>synthesis</span> <span style=''>of</span> <span style=''>3D</span> <span style=''>shapes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>Our</span> <span style=''>key</span> <span style=''>insight</span> <span style=''>is</span> <span style=''>that</span> <span style=''>3D</span> <span style=''>shapes</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.40350877192982454);'>effectively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>organization</span> <span style=''>of</span> <span style=''>parts</span> <span style=''>which</span> <span style=''>reflects</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>intra</span> <span style=''>shape</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>adjacency</span> <span style=''>and</span> <span style=''>symmetry</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style=''>neural</span> <span style=''>net</span> <span style=''>(RvNN)</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>to</span> <span style=''>map</span> <span style=''>a</span> <span style=''>flat</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>part</span> <span style=''>layout</span> <span style=''>to</span> <span style=''>a</span> <span style=''>compact</span> <span style=''>code</span> <span style=''>The</span> <span style=''>code</span> <span style='background-color:rgba(0, 255, 0, 0.40350877192982454);'>effectively</span> <span style=''>captures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>of</span> <span style=''>man</span> <span style=''>made</span> <span style=''>3D</span> <span style=''>objects</span> <span style=''>of</span> <span style=''>varying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>complexities</span> <span style=''>despite</span> <span style=''>being</span> <span style=''>fixed</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>dimensional</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>decoder</span> <span style=''>maps</span> <span style=''>a</span> <span style=''>code</span> <span style=''>back</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>is</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinearity</span> <span style=''>in</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>tensor</span> <span style=''>space</span> <span style=''>is</span> <span style=''>broken</span> <span style=''>into</span> <span style=''>simple</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>naive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerably</span> <span style=''>improves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style=''>function</span> <span style=''>class</span> <span style=''>under</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>To</span> <span style=''>estimate</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>a</span> <span style=''>summary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistic</span> <span style=''>of</span> <span style=''>a</span> <span style=''>real</span> <span style=''>complex</span> <span style=''>network</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style=''>Sketch</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cardinality</span> <span style=''>data</span> <span style=''>arises</span> <span style=''>in</span> <span style=''>many</span> <span style=''>domains</span> <span style=''>and</span> <span style=''>poses</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>both</span> <span style=''>modeling</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>models</span> <span style=''>are</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>data</span> <span style=''>but</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsuitable</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cardinality</span> <span style='background-color:rgba(255, 0, 0, 0.40246913580246907);'>variables</span> <span style=''>The</span> <span style=''>count</span> <span style=''>min</span> <span style=''>(CM)</span> <span style=''>sketch</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.4084507042253521);'>estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cardinality</span> <span style=''>data</span> <span style=''>but</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>scale</span> <span style=''>well</span> <span style=''>beyond</span> <span style=''>a</span> <span style=''>few</span> <span style='background-color:rgba(255, 0, 0, 0.40246913580246907);'>variables</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>bring</span> <span style=''>together</span> <span style=''>the</span> <span style=''>ideas</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>count</span> <span style=''>sketches</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.4084507042253521);'>estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cardinality</span> <span style=''>streams</span> <span style=''>of</span> <span style=''>data</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3939393939393939);'>approximations</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style='background-co ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Environments</span> <span style=''>in</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>Dex</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>toolkit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specialized</span> <span style=''>for</span> <span style=''>training</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continual</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style=''>the</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continual</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>is</span> <span style=''>solved</span> <span style=''>using</span> <span style=''>optimal</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialization</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>first</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>easier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>produce</span> <span style=''>vastly</span> <span style=''>superior</span> <span style=''>results</span> <span style=''>than</span> <span style=''>standard</span> <span style=''>methods</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>baseline</span> <span style=''>method</span> <span style=''>across</span> <span style=''>ten</span> <span style=''>Dex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>We</span> <span style=''>finally</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>saliency</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style=''>analysis</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>shows</span> <span style=''>the</span> <span style=''>impact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>on</span> <span style=''>netwo ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.08751334044823907)
# 	processing (0.10209889718961224)
# 	experimental (0.12984702952685878)
# 	architecture (0.08288865172536464)
# 	segmentation (0.07186054784774101)
# 	information (0.2472429740305941)
# 	detection (0.12379935965848453)
# 	different (0.2632515119174671)
# 	convolutional (0.12735681252223408)
# 	recognition (0.13340448239060831)
#
# Some Statistics words are:
# 	stochastic (0.13172448466566114)
# 	variables (0.14278531925590748)
# 	theoretical (0.15635997988939165)
# 	estimation (0.17194570135746606)
# 	statistical (0.15535444947209653)
# 	distribution (0.19054801407742583)
# 	algorithm (0.3911513323278029)
# 	inference (0.1885369532428356)
# 	dimensional (0.18803418803418803)
# 	regression (0.17747611865258925)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="efe76ecf-92f0-4099-a1bf-fa58b0522b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efe76ecf-92f0-4099-a1bf-fa58b0522b53")) {                    Plotly.newPlot(                        "efe76ecf-92f0-4099-a1bf-fa58b0522b53",                        [{"x":["semantics","extensions","optimization","equilibrium","rewriting","represent","characterize","reasoning","establish","understanding","properties","generalize","propositional","preference","interpreted","interpretation","framework","associated","equivalence","essential","formalism","complexity","introduce","interchangeability","representation","restricting","generators","preferences","guarantees","previously","techniques","generator","qualitative","variables","probabilistic","empirical","different","numerical","shortcomings","overconfidence","foundation","surprisingly","regression","population","intuition","representations","challenge","outperform","aggregation","information","modifications","understood","relational","correspond","empirically","predicting","comparing","challenging","performance","minimizer","equations","simulations","shrinkage","criterion","solutions","thresholding","resulting","responsible","iterative","minimizing","convergence","attention","estimating","significant","algorithm","penalized","confounder","confounding","typically","multivariate","dimensions","detecting","influence","characteristic","concentration","eigenspaces","dependences","predictor","coefficients","quantitatively","covariance","potential","correlated","assumption","describing","independence","statistical","orientation","practical","algorithms","accelerator","sequences","therefore","occlusion","estimated","implementation","important","concurrent","estimation","employing","experimental","pyramidal","benchmark","correlates","parameter","stochastic","parameters","blackwellized","variational","similarities","gradients","efficiently","parallelized","inference","interesting","distribution","expectation","continuous","performing","intelligently","constructing","furthermore","trivially","illustrated","universal","percentage","weighting","consequences","consistency","simulated","existence","minimization","equivalent","benchmarks","substantially","conditions","theoretical","contributions","reinterpret","achieving","linearity","workhorse","impressive","following","demonstrate","substantial","knowledge","incorporates","significance","perceptual","structure","isolation","interests","efficient","principled","heuristic","scenarios","iteration","increasingly","especially","catastrophic","including","theoretically","assumptions","reachable","relationships","unavoidable","restrictive","preliminary","optimally","generally","investigated","experiences","introduces","experiments","confidence","subspaces","experience","calculates","increasing","exploiting","suggested","detriment","nevertheless","reinforcement","computational","generalization","additionally","intervals","designing","introduced","compositions","applications","developed","extremely","intrinsic","summarize","architectural","particular","development","recurrent","community","reservoir","advancements","hierarchical","computing","guaranteed","clustering","occurring","detection","frequently","constrained","unconstrained","relaxation","functions","fractional","relaxations","application","formulation","intuitive","incoherent","corresponding","probability","necessary","constraint","currently","structural","satisfies","completion","uniformly","recovered","proportional","incoherence","procedure","completing","according","advantages","individual","efficiency","discrimination","maximizing","technique","discriminant","multilinear","maximizes","prediction ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounder
# 	dependences
# 	blackwellized
# 	mcallester
# 	katehakis
# 	multiplications
# 	layerwise
# 	practicing
# 	sparsification
# 	eigenstructures
# 	distinguishability
# 	datapoint
# 	lojasiewicz
# 	hypernetworks
# 	hypernetwork
# 	irregularly
# 	invertibility
# 	wirtinger
# 	convexification
# 	commonplace
# Some words which never appear in Statistics papers:
# 	propositional
# 	interchangeability
# 	accelerator
# 	concurrent
# 	reinterpret
# 	timescale
# 	skeletons
# 	traversal
# 	extractive
# 	occlusions
# 	aesthetics
# 	derivational
# 	paradigmatic
# 	misclassifications
# 	misclassified
# 	photographs
# 	concatenating
# 	quantizing
# 	abstractions
# 	interoperability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059413816312795e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
